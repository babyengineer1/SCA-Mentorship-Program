# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer = pd.read_csv("customer.csv")
invoice = pd.read_csv("Invoice.csv")
invoiceline = pd.read_csv("InvoiceLine.csv")
track = pd.read_csv("Track.csv")
genre = pd.read_csv("Genre.csv")

# %%
customer.head(3)
# Out:
#    CustomerId FirstName   LastName  \
# 0           1      Luís  Gonçalves
# 1           2    Leonie     Köhler
# 2           3  François   Tremblay
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               NaN
# 2                                               NaN
#
#                            Address                 City State  Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP   Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart   NaN  Germany
# 2                1498 rue Bélanger             Montréal    QC   Canada
#
#   PostalCode               Phone                 Fax                  Email  \
# 0  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566   luisg@embraer.com.br
# 1      70174    +49 0711 2842222                 NaN  leonekohler@surfeu.de
# 2    H2G 1A7   +1 (514) 721-4711                 NaN    ftremblay@gmail.com
#
# ...

# %%
invoice.head(2)
# Out:
#    InvoiceId  CustomerId  InvoiceDate           BillingAddress BillingCity  \
# 0          1           2          NaN  Theodor-Heuss-Straße 34   Stuttgart
# 1          2           4          NaN         Ullevålsveien 14        Oslo
#
#   BillingState BillingCountry BillingPostalCode  Total
# 0          NaN        Germany             70174   1.98
# 1          NaN         Norway              0171   3.96

# %%
invoiceline.head(2)
# Out:
#    InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0              1          1        2       0.99         1
# 1              2          1        4       0.99         1

# %%
track.head(2)
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
#
#    GenreId                                   Composer  Milliseconds     Bytes  \
# 0        1  Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1        1                                        NaN        342562   5510424
#
#    UnitPrice
# 0       0.99
# 1       0.99

# %%
genre.head(2)
# Out:
#    GenreId  Name
# 0        1  Rock
# 1        2  Jazz

# %% [markdown]
# # Question_1

# %%
best_customer = invoice["Total"].idxmax()

# %%
best_customer
# Out:
# 403

# %%
invoice.loc[best_customer, ["BillingCity", "Total"]]
# Out:
# BillingCity    Prague
# Total           25.86
# Name: 403, dtype: object

# %% [markdown]
# # Question_2

# %%
df = invoice[["BillingCountry", "Total"]]

# %%
df.sort_values(["Total"], ascending=False)
# Out:
#      BillingCountry  Total
# 403  Czech Republic  25.86
# 298             USA  23.86
# 95          Hungary  21.86
# 193         Ireland  21.86
# 200             USA  18.86
# 88          Austria  18.86
# 87            Chile  17.91
# 305  Czech Republic  16.86
# 312          France  16.86
# 102             USA  15.86
# 207          Norway  15.86
# 192         Germany  14.91
# 116          France  13.86
# 151  United Kingdom  13.86
# 291           Italy  13.86
# 46           Canada  13.86
# 172           Spain  13.86
# 375          Canada  13.86
# 340             USA  13.86
# 165          Brazil  13.86
# 53   United Kingdom  13.86
# 158          Canada  13.86
# 109          Canada  13.86
# 347       Argentina  13.86
# 60           Canada  13.86
# 326          Brazil  13.86
# 368  United Kingdom  13.86
# 144             USA  13.86
# 67           Brazil  13.86
# 382          Brazil  13.86
# ..              ...    ...
# 166             USA   0.99
# 299          France   0.99
# ...

# %%
new_df = pd.merge(customer, invoice)

# %%
new_df.head(2)
# Out:
#    CustomerId FirstName   LastName  \
# 0           1      Luís  Gonçalves
# 1           1      Luís  Gonçalves
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1  Embraer - Empresa Brasileira de Aeronáutica S.A.
#
#                            Address                 City State Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
# 1  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
#
#   PostalCode               Phone  ...                  Email SupportRepId  \
# 0  12227-000  +55 (12) 3923-5555  ...   luisg@embraer.com.br            3
# 1  12227-000  +55 (12) 3923-5555  ...   luisg@embraer.com.br            3
#
#    InvoiceId  InvoiceDate                   BillingAddress  \
# 0         98          NaN  Av. Brigadeiro Faria Lima, 2170
# 1        121          NaN  Av. Brigadeiro Faria Lima, 2170
#
# ...

# %% [markdown]
# # Question_3

# %%
highest_total = new_df["Total"].idxmax()

# %%
highest_total
# Out:
# 41

# %%
new_df.loc[highest_total, ["FirstName", "LastName", "Total"]]
# Out:
# FirstName    Helena
# LastName       Holý
# Total         25.86
# Name: 41, dtype: object

# %% [markdown]
# # Question_4

# %%
genre.rename(columns={'Name':'Genrename'}, inplace=True)

# %%
genre.head(2)
# Out:
#    GenreId Genrename
# 0        1      Rock
# 1        2      Jazz

# %%
track_and_genre = pd.merge(track,genre)

# %%
track_and_genre.head(2)
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
#
#    GenreId                                   Composer  Milliseconds     Bytes  \
# 0        1  Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1        1                                        NaN        342562   5510424
#
#    UnitPrice Genrename
# 0       0.99      Rock
# 1       0.99      Rock

# %%
invoiceline_and_invoice = pd.merge(invoiceline,invoice)

# %%
invoiceline_and_invoice.head(2)
# Out:
#    InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity  CustomerId  \
# 0              1          1        2       0.99         1           2
# 1              2          1        4       0.99         1           2
#
#    InvoiceDate           BillingAddress BillingCity BillingState  \
# 0          NaN  Theodor-Heuss-Straße 34   Stuttgart          NaN
# 1          NaN  Theodor-Heuss-Straße 34   Stuttgart          NaN
#
#   BillingCountry BillingPostalCode  Total
# 0        Germany             70174   1.98
# 1        Germany             70174   1.98

# %%
new_merge_df = pd.merge(track_and_genre,invoiceline_and_invoice )

# %%
new_merge_df.head(2)
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
#
#    GenreId                                   Composer  Milliseconds     Bytes  \
# 0        1  Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1        1                                        NaN        342562   5510424
#
#    UnitPrice Genrename  ...   InvoiceId  Quantity  CustomerId  InvoiceDate  \
# 0       0.99      Rock  ...         108         1          47          NaN
# 1       0.99      Rock  ...           1         1           2          NaN
#
#             BillingAddress BillingCity BillingState BillingCountry  \
# 0   Via Degli Scipioni, 43        Rome           RM          Italy
# 1  Theodor-Heuss-Straße 34   Stuttgart          NaN        Germany
#
#   BillingPostalCode Total
# 0             00192  5.94
# ...

# %%
new_merge_df1 = pd.merge(new_merge_df,customer)

# %%
new_merge_df1.head(2)
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        5                     Princess of the Dawn        3            2
#
#    GenreId                                   Composer  Milliseconds     Bytes  \
# 0        1  Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1        1                 Deaffy & R.A. Smith-Diesel        375418   6290521
#
#    UnitPrice Genrename     ...       Company                 Address  City  \
# 0       0.99      Rock     ...           NaN  Via Degli Scipioni, 43  Rome
# 1       0.99      Rock     ...           NaN  Via Degli Scipioni, 43  Rome
#
#    State  Country PostalCode            Phone  Fax                   Email  \
# 0     RM    Italy      00192  +39 06 39733434  NaN  lucas.mancini@yahoo.it
# 1     RM    Italy      00192  +39 06 39733434  NaN  lucas.mancini@yahoo.it
#
#   SupportRepId
# 0            5
# ...

# %%
new_merge_df2 = new_merge_df1.drop_duplicates(subset='Email', keep='first', inplace=False)

# %%
genre_rock = new_merge_df2.loc[(new_merge_df1['Genrename']=='Rock'),['Email','FirstName','LastName','Genrename']]

# %%
genre_rock.sort_values(['Email'], ascending = True).head(3)
# Out:
#                        Email  FirstName  LastName Genrename
# 2164  aaronmitchell@yahoo.ca      Aaron  Mitchell      Rock
# 836         alero@uol.com.br  Alexandre     Rocha      Rock
# 1822  astrid.gruber@apple.at     Astrid    Gruber      Rock

# %% [markdown]
# # Question_5

# %%
spent = pd.DataFrame(new_merge_df1.groupby(['BillingCountry', "Genrename"], as_index=False)['UnitPrice'].sum())
spent.head()
# Out:
#   BillingCountry           Genrename  UnitPrice
# 0      Argentina  Alternative & Punk       8.91
# 1      Argentina      Easy Listening       1.98
# 2      Argentina                Jazz       1.98
# 3      Argentina               Latin       7.92
# 4      Argentina               Metal       6.93

# %%
spent_in_total = pd.DataFrame(spent.groupby('BillingCountry', as_index=False)['UnitPrice'].max())
spent_in_total.head()
# Out:
#   BillingCountry  UnitPrice
# 0      Argentina       8.91
# 1      Australia      21.78
# 2        Austria      14.85
# 3        Belgium      20.79
# 4         Brazil      80.19

# %%
pd.merge(spent_in_total, spent, on = ['UnitPrice', 'BillingCountry'], how = 'inner')
# Out:
#     BillingCountry  UnitPrice           Genrename
# 0        Argentina       8.91  Alternative & Punk
# 1        Argentina       8.91                Rock
# 2        Australia      21.78                Rock
# 3          Austria      14.85                Rock
# 4          Belgium      20.79                Rock
# 5           Brazil      80.19                Rock
# 6           Canada     105.93                Rock
# 7            Chile       8.91                Rock
# 8   Czech Republic      24.75                Rock
# 9          Denmark      20.79                Rock
# 10         Finland      17.82                Rock
# 11          France      64.35                Rock
# 12         Germany      61.38                Rock
# 13         Hungary      10.89                Rock
# 14           India      24.75                Rock
# 15         Ireland      13.93            TV Shows
# 16           Italy      17.82                Rock
# 17     Netherlands      17.82                Rock
# ...
